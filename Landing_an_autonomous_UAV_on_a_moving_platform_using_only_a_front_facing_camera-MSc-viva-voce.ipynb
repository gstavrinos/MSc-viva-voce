# %% [markdown]
# <center>
# <img src="resources/logo.png">
#
# <h1><span style="color:#8e1731">Landing an autonomous UAV on a moving platform using only a front facing camera</span></h1>
#
#
# <h4>by</h4>
# <h3>George Stavrinos</h3>
#
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 0</span></h1>
# <h2>The outline</h2>
#
# <br>
# <br>
# </center>
#
# <h3>
# <ul>
#      <li> Chapter 1: What is the project about?
#      <li> Chapter 2: Why this project?
#      <li> Chapter 3: Research areas of interest
#      <li> Chapter 4: Summary of the state of the art
#      <li> Chapter 5: Development strategy
#      <li> Chapter 6: The Hardware
#      <li> Chapter 7: Landing zone detection
#      <li> Chapter 8: Landing zone velocity estimation
#      <li> Chapter 9: Visual Odometry
#      <li> Chapter 10: Global planning
#      <li> Chapter 11: Gazebo simulation
#      <li> Chapter 12: Local planning
#      <li> Chapter 13: System architecture
#      <li> Chapter 14: Results
#      <li> Chapter 15: Future Work
#      <li> Chapter 16: The end
# </ul>
# </h3>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 1</span></h1>
# <h2>What is it about?</h2>
#
# <br>
# <br>
#
# <img src="resources/fov.png"><br><h3>The difference between already implemented methods and the proposed one.</h3></img>
#
# <br>
# <br>
# <br>
#
# <img src="resources/general_goal.png"><br><h3>The general idea of the project.</h3></img>
#
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 2</span></h1>
# <h2>Why this research topic?</h2>
#
# <br>
# <br>
# </center>
#
# <h3>
# <ul>
#      <li> No implementation in the current state of the art.
#      <li> Implications in the current literature that something like this would be useful.
#      <li> Pushing the capabilities of consumer-grade UAVs.
#      <li> Personal interest and challenge.
#      <li> Experiments with global planners that need to reach a moving target
#      <li> Planning when to do a risky move like turning off the UAV's motors
#      <li> Experiments with visual odometry
#      <li> Physics-based planning
# </ul>
# </h3>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 3</span></h1>
# <h2>Research areas of interest</h2>
#
# <br>
# <br>
# </center>
#
# <h3>
# <ul>
#      <li> Robot development framework
#      <li> Camera-based object detection
#      <li> 3D Global planning
#      <li> Visual odometry
#      <li> 3D Local planning
#      <li> Other similar implementations
# </ul>
# </h3>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 4</span></h1>
# <h2>Summary of state of the art</h2>
#
#
# <style>
# table {
#     font-family: arial, sans-serif;
#     border-collapse: collapse;
#     width: 100%;
# }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align: left;
#     padding: 8px;
# }
#
# tr:nth-child(even) {
#     background-color: #dddddd;
# }
# </style>
#
# <h3>
# <table>
#   <tr>
#     <th>Category</th>
#     <th>Method</th>
#     <th>To be used without modifications</th>
#     <th>Hands-on investigation needed</th>
#   </tr>
#   <tr>
#     <td>Robot Development Tool</td>
#     <td>ROS</td>
#     <td>Yes</td>
#     <td>No</td>
#   </tr>
#   <tr>
#     <td>Moving platform detection</td>
#     <td>ar_track_alvar</td>
#     <td>Yes, with minor modifications</td>
#     <td>No</td>
#   </tr>
#   <tr>
#     <td>Global planner</td>
#     <td>New implementation</td>
#     <td>NA</td>
#     <td>NA</td>
#   </tr>
#   <tr>
#     <td>Visual odometry</td>
#     <td>libviso2</td>
#     <td>Yes</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td>Visual odometry</td>
#     <td>ETH visual odometry</td>
#     <td>Yes</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td>Local planner</td>
#     <td>New implementation</td>
#     <td>NA</td>
#     <td>NA</td>
#   </tr>
# </table>
# </h3>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 5</span></h1>
# <h2>Development Strategy</h2>
#
# <br>
# <br>
#
# <img src="resources/spiral_model.png"><br><h3>Illustration of the spiral software development model.</h3></img>
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 6</span></h1>
# <h2>The Hardware</h2>
# </center>
#
# <div>
#
# <p>
# <img src="resources/static_bebop.jpg" style="width: 35%; height: 35%; float: right">
# </p>
# <p>
# <h3>
# Keypoints:
# <ul>
#      <li> Inertia Measurement Unit
#      <li> Front facing fish-eye camera
#      <li> Global Positioning System sensor
#      <li> Motion tracking sensor
#      <li> Ability to stream image data through WiFi
#      <li> Available ROS drivers
# </ul>
# </h3>
# </p>
# </div>
#
# <center>
# <img src="resources/cool_bebop.gif">
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 7</span></h1>
# <h2>Landing zone detection</h2>
# <br><br>
#
# <img src="resources/camera_calibration.png"><h3>Camera calibration</h3></img>
#
# <br>
#
# <img src="resources/ar_markers.png"><h3>AR Markers</h3></img>
#
# <br>
#
# <img src="resources/helipad_size.jpg" style="width: 65%; height: 65%"><h3>Helipad Size compared to the drone</h3></img>
#
# <br>
#
# <img src="resources/helipad_detection.png"><h3>Helipad Detection</h3></img>
#
#
#
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 8</span></h1>
# <h2>Landing zone velocity estimation</h2>
# <br><br>
#
# \begin{equation}
# v_x= \frac{\Delta x_x}{\Delta t}
# \end{equation}
#
# \begin{equation}
# v_y= \frac{\Delta x_y}{\Delta t}
# \end{equation}
#
# \begin{equation}
# v_z= \frac{\Delta x_z}{\Delta t}
# \end{equation}
#
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 9</span></h1>
# <h2>Visual Odometry</h2>
# <br><br>
# </center>
# <h3>
# Procedure:
# <ol>
#     <li> Test ETH implementation. Result: IMU raw data needed to provide accurate results.
#     <li> Test libviso2 combined with the robot_localization package. Result: IMU raw data needed to provide accurate results.
#     <li> Final result: Rely on the provided odomentry based on the on-board motion tracker.
# </ol>
# </h3>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 10</span></h1>
# <h2>Global Planning</h2>
# <br><br>
# </center>
# <h3>
# Two alternatives:
# <ol>
#     <li> First point that can be reached based on kinematic limitations.
#     <li> Point that requires the lowest velocity.
# </ol>
# </h3>
#
# <img src="resources/global_planning_strategies.png"><h3>The two global planning strategies</h3></img>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 14</span></h1>
# <h2>Results</h2>
#
# <br><br>
# <video controls width="640" height="480" src="resources/moving_plat_demo1.mp4"/>
# </center>

# %% [markdown]
# <center>
# <video controls width="640" height="480" src="resources/moving_plat_demo2.mp4"/>
# </center>

# %% [markdown]
# <br><br><br><br><br>
# <center><h1><span style="color:#8e1731">Chapter 16</span></h1>
# </center>
#
# <div>
# <center>
# <img src="resources/the_end.gif">
#
# <h2>Questions?</h2>
# </center>
